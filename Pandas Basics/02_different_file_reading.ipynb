# %% [markdown]
# # __Different File  Reading__

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Reading CSV file

# %%
df = pd.read_csv(r"../Datasets/covid_19.csv")
df
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 0                NaN            Afghanistan  33.939110  67.709953  2020-01-22
# 1                NaN                Albania  41.153300  20.168300  2020-01-22
# 2                NaN                Algeria  28.033900   1.659600  2020-01-22
# 3                NaN                Andorra  42.506300   1.521800  2020-01-22
# 4                NaN                 Angola -11.202700  17.873900  2020-01-22
# ...              ...                    ...        ...        ...         ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
# ...

# %% [markdown]
# Reading Excel File

# %%
df = pd.read_excel(r'../Datasets/sample.xlsx')
df.tail()
# Out:
#     Unnamed: 0   Unnamed: 1               Unnamed: 2 Unnamed: 3  \
# 46         NaN    Logistics  Transportation Planning   Patricia
# 47         NaN    Logistics   Inventory Optimization    Quentin
# 48         NaN  Engineering           Product Design     Rachel
# 49         NaN  Engineering       System Integration        Sam
# 50         NaN  Engineering        Prototype Testing        Tom
#
#              Unnamed: 4 Unnamed: 5           Unnamed: 6 Unnamed: 7
# 46  2024-01-29 00:00:00         30  2024-02-28 00:00:00          1
# 47  2024-03-29 00:00:00         20  2024-04-18 00:00:00          0
# 48  2024-01-02 00:00:00         25  2024-01-27 00:00:00        0.2
# 49  2024-02-02 00:00:00         22  2024-02-24 00:00:00          0
# 50  2024-02-23 00:00:00         27  2024-03-21 00:00:00          0

# %%
df = pd.read_clipboard(sep='/')
df
# Out:
#                                                     [
# 0                                                   {
# 1                                            "id": 1,
# 2                            "name": "Alice Johnson",
# 3                                          "age": 29,
# 4                        "department": "Engineering",
# 5               "email": "alice.johnson@example.com",
# 6                "skills": "Python, JavaScript, C++",
# 7                                "is_full_time": true
# 8                                                  },
# 9                                                   {
# 10                                           "id": 2,
# 11                               "name": "Bob Smith",
# 12                                         "age": 35,
# 13                   "department": "Human Resources",
# 14                  "email": "bob.smith@example.com",
# 15          "skills": "Communication, Recruitment,...
# ...

# %%
df = pd.read_json(r'../Datasets/sample.json')
df
# Out:
#    id           name  age       department                      email  \
# 0   1  Alice Johnson   29      Engineering  alice.johnson@example.com
# 1   2      Bob Smith   35  Human Resources      bob.smith@example.com
# 2   3  Charlie Brown   24        Marketing  charlie.brown@example.com
#
#                                             skills  is_full_time
# 0                          Python, JavaScript, C++          True
# 1  Communication, Recruitment, Conflict Resolution          True
# 2   SEO, Content Creation, Social Media Management         False

# %% [markdown]
# we can read sql file with pd.read_sql <br/>
# we can read html file's table with pd.read_html <br/>
# we can read txt file with pd.read_csv but with seprator sep=","
