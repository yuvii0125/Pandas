# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'../Datasets/covid_19.csv')
df.head()
# Out:
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22          0
# 2            NaN        Algeria  28.03390   1.659600  2020-01-22          0
# 3            NaN        Andorra  42.50630   1.521800  2020-01-22          0
# 4            NaN         Angola -11.20270  17.873900  2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe
# 2       0          0       0                 Africa
# 3       0          0       0                 Europe
# 4       0          0       0                 Africa

# %%
df.shape # (rows, columns)
# Out:
# (49068, 10)

# %%
len(df) # number of rows , df.shape[0] also give the same result
# Out:
# 49068

# %% [markdown]
# # __Seeing Top N and Bottom N rows__

# %% [markdown]
# df.head(n) :- top n rows <br/>
# df.tail(n) :- top n columns

# %%
df.head()
# Out:
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22          0
# 2            NaN        Algeria  28.03390   1.659600  2020-01-22          0
# 3            NaN        Andorra  42.50630   1.521800  2020-01-22          0
# 4            NaN         Angola -11.20270  17.873900  2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe
# 2       0          0       0                 Africa
# 3       0          0       0                 Europe
# 4       0          0       0                 Africa

# %%
df.tail()
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
#        Confirmed  Deaths  Recovered  Active             WHO Region
# 49063        865      14        734     117                 Africa
# 49064       1691     483        833     375  Eastern Mediterranean
# 49065        354       7        328      19                 Africa
# 49066       7235      60       6028    1147                 Europe
# 49067        505      12        128     365                 Africa

# %%
df.head(7) # first 7 rows
# Out:
#   Province/State       Country/Region       Lat       Long        Date  \
# 0            NaN          Afghanistan  33.93911  67.709953  2020-01-22
# 1            NaN              Albania  41.15330  20.168300  2020-01-22
# 2            NaN              Algeria  28.03390   1.659600  2020-01-22
# 3            NaN              Andorra  42.50630   1.521800  2020-01-22
# 4            NaN               Angola -11.20270  17.873900  2020-01-22
# 5            NaN  Antigua and Barbuda  17.06080 -61.796400  2020-01-22
# 6            NaN            Argentina -38.41610 -63.616700  2020-01-22
#
#    Confirmed  Deaths  Recovered  Active             WHO Region
# 0          0       0          0       0  Eastern Mediterranean
# 1          0       0          0       0                 Europe
# 2          0       0          0       0                 Africa
# 3          0       0          0       0                 Europe
# 4          0       0          0       0                 Africa
# ...

# %%
df.tail(7) # last 7 rows
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 49061            NaN            South Sudan   6.877000  31.307000  2020-07-27
# 49062            NaN         Western Sahara  24.215500 -12.885800  2020-07-27
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
#        Confirmed  Deaths  Recovered  Active             WHO Region
# 49061       2305      46       1175    1084                 Africa
# 49062         10       1          8       1                 Africa
# 49063        865      14        734     117                 Africa
# 49064       1691     483        833     375  Eastern Mediterranean
# ...

# %%
df.columns # column names
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', 'Date', 'Confirmed',
#        'Deaths', 'Recovered', 'Active', 'WHO Region'],
#       dtype='object')

# %%
df.info() # information about the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49068 entries, 0 to 49067
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  14664 non-null  object
#  1   Country/Region  49068 non-null  object
#  2   Lat             49068 non-null  float64
#  3   Long            49068 non-null  float64
#  4   Date            49068 non-null  object
#  5   Confirmed       49068 non-null  int64
#  6   Deaths          49068 non-null  int64
#  7   Recovered       49068 non-null  int64
#  8   Active          49068 non-null  int64
#  9   WHO Region      49068 non-null  object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 3.7+ MB

# %%
df.memory_usage(deep=True) # memory usage of each column
# Out:
# Index                 132
# Province/State    1973812
# Country/Region    2800260
# Lat                392544
# Long               392544
# Date              2895012
# Confirmed          392544
# Deaths             392544
# Recovered          392544
# Active             392544
# WHO Region        2888056
# dtype: int64

# %%
df.dtypes # data types of each column
# Out:
# Province/State     object
# Country/Region     object
# Lat               float64
# Long              float64
# Date               object
# Confirmed           int64
# Deaths              int64
# Recovered           int64
# Active              int64
# WHO Region         object
# dtype: object

# %% [markdown]
# ## __Converting column's data type__

# %%
df['Lat'] = df['Lat'].astype('float32') # change data type of a column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49068 entries, 0 to 49067
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  14664 non-null  object
#  1   Country/Region  49068 non-null  object
#  2   Lat             49068 non-null  float32
#  3   Long            49068 non-null  float64
#  4   Date            49068 non-null  object
#  5   Confirmed       49068 non-null  int64
#  6   Deaths          49068 non-null  int64
#  7   Recovered       49068 non-null  int64
#  8   Active          49068 non-null  int64
#  9   WHO Region      49068 non-null  object
# dtypes: float32(1), float64(1), int64(4), object(4)
# memory usage: 3.6+ MB

# %%
df.describe() # summary statistics of the data
# Out:
#                 Lat          Long     Confirmed         Deaths     Recovered  \
# count  49068.000000  49068.000000  4.906800e+04   49068.000000  4.906800e+04
# mean      21.433729     23.528236  1.688490e+04     884.179160  7.915713e+03
# std       24.950048     70.442740  1.273002e+05    6313.584411  5.480092e+04
# min      -51.796299   -135.000000  0.000000e+00       0.000000  0.000000e+00
# 25%        7.873054    -15.310100  4.000000e+00       0.000000  0.000000e+00
# 50%       23.634501     21.745300  1.680000e+02       2.000000  2.900000e+01
# 75%       41.204380     80.771797  1.518250e+03      30.000000  6.660000e+02
# max       71.706902    178.065000  4.290259e+06  148011.000000  1.846641e+06
#
#              Active
# count  4.906800e+04
# mean   8.085012e+03
# std    7.625890e+04
# min   -1.400000e+01
# 25%    0.000000e+00
# 50%    2.600000e+01
# 75%    6.060000e+02
# max    2.816444e+06
