# %% [markdown]
# # __4.Query and Oval__

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'..\\Datasets\\Churn.csv')
df
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# 0                yes                     25              265.1
# 1                yes                     26              161.6
# 2                 no                      0              243.4
# 3                 no                      0              299.4
# 4                 no                      0              166.7
# ...              ...                    ...                ...
# 3328             yes                     36              156.2
# 3329              no                      0              231.1
# 3330              no                      0              180.8
# 3331              no                      0              213.8
# 3332             yes                     25              234.4
#
#       total day calls  total day charge  ...  total eve calls  \
# 0                 110             45.07  ...               99
# 1                 123             27.47  ...              103
# 2                 114             41.38  ...              110
# 3                  71             50.90  ...               88
# 4                 113             28.34  ...              122
# ...               ...               ...  ...              ...
# 3328               77             26.55  ...              126
# 3329               57             39.29  ...               55
# 3330              109             30.74  ...               58
# 3331              105             36.35  ...               84
# 3332              113             39.85  ...               82
#
#       total eve charge  total night minutes  total night calls  \
# 0                16.78                244.7                 91
# 1                16.62                254.4                103
# 2                10.30                162.6                104
# 3                 5.26                196.9                 89
# 4                12.61                186.9                121
# ...                ...                  ...                ...
# 3328             18.32                279.1                 83
# 3329             13.04                191.3                123
# 3330             24.55                191.9                 91
# 3331             13.57                139.2                137
# 3332             22.60                241.4                 77
#
#       total night charge  total intl minutes  total intl calls  \
# 0                  11.01                10.0                 3
# 1                  11.45                13.7                 3
# 2                   7.32                12.2                 5
# 3                   8.86                 6.6                 7
# 4                   8.41                10.1                 3
# ...                  ...                 ...               ...
# 3328               12.56                 9.9                 6
# 3329                8.61                 9.6                 4
# 3330                8.64                14.1                 6
# 3331                6.26                 5.0                10
# 3332               10.86                13.7                 4
#
#       total intl charge  customer service calls  churn
# 0                  2.70                       1  False
# 1                  3.70                       1  False
# 2                  3.29                       0  False
# 3                  1.78                       2  False
# 4                  2.73                       3  False
# ...                 ...                     ...    ...
# 3328               2.67                       2  False
# 3329               2.59                       3  False
# 3330               3.81                       2  False
# 3331               1.35                       2  False
# 3332               3.70                       0  False
#
# [3333 rows x 21 columns]

# %% [markdown]
# ## Query

# %% [markdown]
# __One Condition__

# %%
df.columns
# Out:
# Index(['state', 'account length', 'area code', 'phone number',
#        'international plan', 'voice mail plan', 'number vmail messages',
#        'total day minutes', 'total day calls', 'total day charge',
#        'total eve minutes', 'total eve calls', 'total eve charge',
#        'total night minutes', 'total night calls', 'total night charge',
#        'total intl minutes', 'total intl calls', 'total intl charge',
#        'customer service calls', 'churn'],
#       dtype='object')

# %%
df.rename(columns={' state ': 'state'}, inplace=True)

# %%
df['state'] = df['state'].astype(str)

# %%
df.query("`state` in ('KS', 'OH')").head()
# Out:
#     state  account length  area code phone number international plan  \
# 0      KS             128        415     382-4657                 no
# 1      OH             107        415     371-7191                 no
# 3      OH              84        408     375-9999                yes
# 152    OH              65        408     336-7600                 no
# 156    OH              83        415     370-9116                 no
#
#     voice mail plan  number vmail messages  total day minutes  \
# 0               yes                     25              265.1
# 1               yes                     26              161.6
# 3                no                      0              299.4
# 152              no                      0              187.9
# 156              no                      0              337.4
#
#      total day calls  total day charge  ...  total eve calls  \
# 0                110             45.07  ...               99
# 1                123             27.47  ...              103
# 3                 71             50.90  ...               88
# 152              116             31.94  ...              117
# 156              120             57.36  ...              116
#
#      total eve charge  total night minutes  total night calls  \
# 0               16.78                244.7                 91
# 1               16.62                254.4                103
# 3                5.26                196.9                 89
# 152             13.40                227.3                 86
# 156             19.33                153.9                114
#
#      total night charge  total intl minutes  total intl calls  \
# 0                 11.01                10.0                 3
# 1                 11.45                13.7                 3
# 3                  8.86                 6.6                 7
# 152               10.23                 7.5                 6
# 156                6.93                15.8                 7
#
#      total intl charge  customer service calls  churn
# 0                 2.70                       1  False
# 1                 3.70                       1  False
# 3                 1.78                       2  False
# 152               2.03                       1  False
# 156               4.27                       0   True
#
# [5 rows x 21 columns]

# %%
df.query("state in ('KS', 'OH') and `voice mail plan` == 'yes' ").head()
# Out:
#     state  account length  area code phone number international plan  \
# 0      KS             128        415     382-4657                 no
# 1      OH             107        415     371-7191                 no
# 231    OH              63        415     410-3719                yes
# 362    OH              39        415     421-9752                 no
# 451    KS              86        408     339-2616                 no
#
#     voice mail plan  number vmail messages  total day minutes  \
# 0               yes                     25              265.1
# 1               yes                     26              161.6
# 231             yes                     36              199.0
# 362             yes                     36              141.7
# 451             yes                     23              225.5
#
#      total day calls  total day charge  ...  total eve calls  \
# 0                110             45.07  ...               99
# 1                123             27.47  ...              103
# 231              110             33.83  ...              111
# 362              121             24.09  ...              113
# 451              107             38.34  ...              105
#
#      total eve charge  total night minutes  total night calls  \
# 0               16.78                244.7                 91
# 1               16.62                254.4                103
# 231             24.76                197.6                 92
# 362             19.75                222.1                131
# 451             20.94                245.7                 81
#
#      total night charge  total intl minutes  total intl calls  \
# 0                 11.01                10.0                 3
# 1                 11.45                13.7                 3
# 231                8.89                11.0                 6
# 362                9.99                12.0                 5
# 451               11.06                 9.8                 2
#
#      total intl charge  customer service calls  churn
# 0                 2.70                       1  False
# 1                 3.70                       1  False
# 231               2.97                       1  False
# 362               3.24                       1  False
# 451               2.65                       0  False
#
# [5 rows x 21 columns]

# %% [markdown]
# __Sort by multiple columns__

# %%
df.sort_values(by=['state', 'total day calls'], ascending=False).loc[:, ['state', 'total day calls']]

# %% [markdown]
# Sort one column by ascending and other by descending.
#
# Ex: Sort `state` in alphabetical order but `total day calls` in descending order.

# %%
df.sort_values(by=['state', 'total day calls'], ascending=[True, False]).loc[:, ['state', 'total day calls']]
# Out:
#      state  total day calls
# 950     AK              129
# 36      AK              128
# 3088    AK              127
# 718     AK              124
# 2071    AK              121
# ...    ...              ...
# 2819    WY               68
# 3172    WY               67
# 653     WY               65
# 609     WY               55
# 1422    WY               45
#
# [3333 rows x 2 columns]

# %% [markdown]
# __Query using another Python variable__
#
# You can refer to another python variable (`var_name`) in a query using `@var_name`.

# %%
min_day_calls = 120
df.query("state in ('KS', 'OH') and `voice mail plan` == 'yes' and `total day calls` > @min_day_calls").head()
# Out:
#      state  account length  area code phone number international plan  \
# 1       OH             107        415     371-7191                 no
# 362     OH              39        415     421-9752                 no
# 866     OH             119        415     385-7922                 no
# 1066    KS             117        510     385-3263                 no
# 1852    KS             101        510     413-1061                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# 1                yes                     26              161.6
# 362              yes                     36              141.7
# 866              yes                     27              220.1
# 1066             yes                     25              216.0
# 1852             yes                     25              144.1
#
#       total day calls  total day charge  ...  total eve calls  \
# 1                 123             27.47  ...              103
# 362               121             24.09  ...              113
# 866               128             37.42  ...              133
# 1066              140             36.72  ...               69
# 1852              144             24.50  ...              105
#
#       total eve charge  total night minutes  total night calls  \
# 1                16.62                254.4                103
# 362              19.75                222.1                131
# 866              22.80                146.5                 80
# 1066             19.05                267.9                112
# 1852             14.25                240.0                107
#
#       total night charge  total intl minutes  total intl calls  \
# 1                  11.45                13.7                 3
# 362                 9.99                12.0                 5
# 866                 6.59                11.1                 3
# 1066               12.06                11.8                 4
# 1852               10.80                14.5                 3
#
#       total intl charge  customer service calls  churn
# 1                  3.70                       1  False
# 362                3.24                       1  False
# 866                3.00                       0  False
# 1066               3.19                       0  False
# 1852               3.92                       1  False
#
# [5 rows x 21 columns]

# %%
# %%time
min_day_calls = 120
df.query("state in ('KS', 'OH') and `voice mail plan` == 'yes' and `total day calls` > @min_day_calls").head()
# Out:
# CPU times: total: 0 ns
# Wall time: 5.34 ms
#      state  account length  area code phone number international plan  \
# 1       OH             107        415     371-7191                 no
# 362     OH              39        415     421-9752                 no
# 866     OH             119        415     385-7922                 no
# 1066    KS             117        510     385-3263                 no
# 1852    KS             101        510     413-1061                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# 1                yes                     26              161.6
# 362              yes                     36              141.7
# 866              yes                     27              220.1
# 1066             yes                     25              216.0
# 1852             yes                     25              144.1
#
#       total day calls  total day charge  ...  total eve calls  \
# 1                 123             27.47  ...              103
# 362               121             24.09  ...              113
# 866               128             37.42  ...              133
# 1066              140             36.72  ...               69
# 1852              144             24.50  ...              105
#
#       total eve charge  total night minutes  total night calls  \
# 1                16.62                254.4                103
# 362              19.75                222.1                131
# 866              22.80                146.5                 80
# 1066             19.05                267.9                112
# 1852             14.25                240.0                107
#
#       total night charge  total intl minutes  total intl calls  \
# 1                  11.45                13.7                 3
# 362                 9.99                12.0                 5
# 866                 6.59                11.1                 3
# 1066               12.06                11.8                 4
# 1852               10.80                14.5                 3
#
#       total intl charge  customer service calls  churn
# 1                  3.70                       1  False
# 362                3.24                       1  False
# 866                3.00                       0  False
# 1066               3.19                       0  False
# 1852               3.92                       1  False
#
# [5 rows x 21 columns]

# %% [markdown]
# The best part is, filtering using queries can be faster than with `.loc` based calls for large dataframes.

# %% [markdown]
# ### Eval

# %% [markdown]
# __Using df.eval__
#
# You need to pass an expression to evaluate as a string to the `df.eval()` method.

# %%
# %%time
mask = df.eval("state in ('KS', 'OH') and `voice mail plan` == 'yes' and `total day calls` > @min_day_calls")
mask
# Out:
# CPU times: total: 0 ns
# Wall time: 4.49 ms
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 3328    False
# 3329    False
# 3330    False
# 3331    False
# 3332    False
# Length: 3333, dtype: bool

# %%
df.loc[mask , :].head()
# Out:
#      state  account length  area code phone number international plan  \
# 1       OH             107        415     371-7191                 no
# 362     OH              39        415     421-9752                 no
# 866     OH             119        415     385-7922                 no
# 1066    KS             117        510     385-3263                 no
# 1852    KS             101        510     413-1061                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# 1                yes                     26              161.6
# 362              yes                     36              141.7
# 866              yes                     27              220.1
# 1066             yes                     25              216.0
# 1852             yes                     25              144.1
#
#       total day calls  total day charge  ...  total eve calls  \
# 1                 123             27.47  ...              103
# 362               121             24.09  ...              113
# 866               128             37.42  ...              133
# 1066              140             36.72  ...               69
# 1852              144             24.50  ...              105
#
#       total eve charge  total night minutes  total night calls  \
# 1                16.62                254.4                103
# 362              19.75                222.1                131
# 866              22.80                146.5                 80
# 1066             19.05                267.9                112
# 1852             14.25                240.0                107
#
#       total night charge  total intl minutes  total intl calls  \
# 1                  11.45                13.7                 3
# 362                 9.99                12.0                 5
# 866                 6.59                11.1                 3
# 1066               12.06                11.8                 4
# 1852               10.80                14.5                 3
#
#       total intl charge  customer service calls  churn
# 1                  3.70                       1  False
# 362                3.24                       1  False
# 866                3.00                       0  False
# 1066               3.19                       0  False
# 1852               3.92                       1  False
#
# [5 rows x 21 columns]

# %% [markdown]
# __Creating a column with eval method__

# %%
df.eval('minutes_per_call = `total day minutes` / `total day calls`', inplace=True)

# %%
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve charge  total night minutes  \
# 0             45.07  ...             16.78                244.7
# 1             27.47  ...             16.62                254.4
# 2             41.38  ...             10.30                162.6
# 3             50.90  ...              5.26                196.9
# 4             28.34  ...             12.61                186.9
#
#    total night calls  total night charge  total intl minutes  \
# 0                 91               11.01                10.0
# 1                103               11.45                13.7
# 2                104                7.32                12.2
# 3                 89                8.86                 6.6
# 4                121                8.41                10.1
#
#    total intl calls  total intl charge  customer service calls  churn  \
# 0                 3               2.70                       1  False
# 1                 3               3.70                       1  False
# 2                 5               3.29                       0  False
# 3                 7               1.78                       2  False
# 4                 3               2.73                       3  False
#
#    minutes_per_call
# 0          2.410000
# 1          1.313821
# 2          2.135088
# 3          4.216901
# 4          1.475221
#
# [5 rows x 22 columns]

# %%
df.eval('minutes_per_call = `total day minutes` / `total day calls`', inplace=True)

# %%
df.eval('minutes_per_call = `total day minutes` / `total day calls`', inplace=True)

# %% [markdown]
# __Removing Duplicates__

# %% [markdown]
# Removing duplicate items based on one or more columns is another often used data cleaning step. For example, you migh want to keep the very first occurence of a particular value and drop everything afterwards.
#
# When dropping duplicates, you may handle them in 3 ways usually:
# 1. Keep first occurrence only
# 2. Keep last occurrence only
# 3. Remove all if there's more than one occurrence.

# %%
import pandas as pd
df = pd.read_csv(r'..\\Datasets\\Churn.csv')

# %%
df
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# 0                yes                     25              265.1
# 1                yes                     26              161.6
# 2                 no                      0              243.4
# 3                 no                      0              299.4
# 4                 no                      0              166.7
# ...              ...                    ...                ...
# 3328             yes                     36              156.2
# 3329              no                      0              231.1
# 3330              no                      0              180.8
# 3331              no                      0              213.8
# 3332             yes                     25              234.4
#
#       total day calls  total day charge  ...  total eve calls  \
# 0                 110             45.07  ...               99
# 1                 123             27.47  ...              103
# 2                 114             41.38  ...              110
# 3                  71             50.90  ...               88
# 4                 113             28.34  ...              122
# ...               ...               ...  ...              ...
# 3328               77             26.55  ...              126
# 3329               57             39.29  ...               55
# 3330              109             30.74  ...               58
# 3331              105             36.35  ...               84
# 3332              113             39.85  ...               82
#
#       total eve charge  total night minutes  total night calls  \
# 0                16.78                244.7                 91
# 1                16.62                254.4                103
# 2                10.30                162.6                104
# 3                 5.26                196.9                 89
# 4                12.61                186.9                121
# ...                ...                  ...                ...
# 3328             18.32                279.1                 83
# 3329             13.04                191.3                123
# 3330             24.55                191.9                 91
# 3331             13.57                139.2                137
# 3332             22.60                241.4                 77
#
#       total night charge  total intl minutes  total intl calls  \
# 0                  11.01                10.0                 3
# 1                  11.45                13.7                 3
# 2                   7.32                12.2                 5
# 3                   8.86                 6.6                 7
# 4                   8.41                10.1                 3
# ...                  ...                 ...               ...
# 3328               12.56                 9.9                 6
# 3329                8.61                 9.6                 4
# 3330                8.64                14.1                 6
# 3331                6.26                 5.0                10
# 3332               10.86                13.7                 4
#
#       total intl charge  customer service calls  churn
# 0                  2.70                       1  False
# 1                  3.70                       1  False
# 2                  3.29                       0  False
# 3                  1.78                       2  False
# 4                  2.73                       3  False
# ...                 ...                     ...    ...
# 3328               2.67                       2  False
# 3329               2.59                       3  False
# 3330               3.81                       2  False
# 3331               1.35                       2  False
# 3332               3.70                       0  False
#
# [3333 rows x 21 columns]

# %%
df.drop_duplicates('state',keep='first')
pd.set_option('display.max_rows', 10)

# %%
df.drop_duplicates('state',keep='first')
# Out:
#     state  account length  area code phone number international plan  \
# 0      KS             128        415     382-4657                 no
# 1      OH             107        415     371-7191                 no
# 2      NJ             137        415     358-1921                 no
# 4      OK              75        415     330-6626                yes
# 5      AL             118        510     391-8027                yes
# ..    ...             ...        ...          ...                ...
# 98     MS             120        408     355-6291                 no
# 196    TN              78        415     332-6934                 no
# 212    PA              82        415     333-5609                 no
# 290    CT             199        415     393-6733                 no
# 377    ND              79        408     363-3515                 no
#
#     voice mail plan  number vmail messages  total day minutes  \
# 0               yes                     25              265.1
# 1               yes                     26              161.6
# 2                no                      0              243.4
# 4                no                      0              166.7
# 5                no                      0              223.4
# ..              ...                    ...                ...
# 98               no                      0              212.1
# 196              no                      0              149.7
# 212             yes                     24              155.2
# 290             yes                     34              230.6
# 377              no                      0              205.7
#
#      total day calls  total day charge  ...  total eve calls  \
# 0                110             45.07  ...               99
# 1                123             27.47  ...              103
# 2                114             41.38  ...              110
# 4                113             28.34  ...              122
# 5                 98             37.98  ...              101
# ..               ...               ...  ...              ...
# 98               131             36.06  ...              104
# 196              119             25.45  ...              115
# 212              131             26.38  ...              106
# 290              121             39.20  ...               99
# 377              123             34.97  ...              108
#
#      total eve charge  total night minutes  total night calls  \
# 0               16.78                244.7                 91
# 1               16.62                254.4                103
# 2               10.30                162.6                104
# 4               12.61                186.9                121
# 5               18.75                203.9                118
# ..                ...                  ...                ...
# 98              17.80                167.2                 96
# 196             15.49                261.5                126
# 212             20.78                122.4                 68
# 290             18.65                299.3                 94
# 377             18.23                226.1                106
#
#      total night charge  total intl minutes  total intl calls  \
# 0                 11.01                10.0                 3
# 1                 11.45                13.7                 3
# 2                  7.32                12.2                 5
# 4                  8.41                10.1                 3
# 5                  9.18                 6.3                 6
# ..                  ...                 ...               ...
# 98                 7.52                 5.3                 5
# 196               11.77                 9.7                 8
# 212                5.51                10.7                 3
# 290               13.47                 8.0                 2
# 377               10.17                 6.7                18
#
#      total intl charge  customer service calls  churn
# 0                 2.70                       1  False
# 1                 3.70                       1  False
# 2                 3.29                       0  False
# 4                 2.73                       3  False
# 5                 1.70                       0  False
# ..                 ...                     ...    ...
# 98                1.43                       1   True
# 196               2.62                       0  False
# 212               2.89                       1  False
# 290               2.16                       0  False
# 377               1.81                       1  False
#
# [51 rows x 21 columns]

# %%
pd.reset_option('display.max_rows')

# %%
df.drop_duplicates(subset=['state','area code'],keep='first') #to have only last occurrence keep='last'
# Out:
#     state  account length  area code phone number international plan  \
# 0      KS             128        415     382-4657                 no
# 1      OH             107        415     371-7191                 no
# 2      NJ             137        415     358-1921                 no
# 3      OH              84        408     375-9999                yes
# 4      OK              75        415     330-6626                yes
# ..    ...             ...        ...          ...                ...
# 707    CT              84        510     351-1007                 no
# 710    TN              69        510     358-1912                 no
# 760    NC             128        510     417-5067                 no
# 777    ND             135        510     378-4013                yes
# 814    WA              75        510     367-1424                 no
#
#     voice mail plan  number vmail messages  total day minutes  \
# 0               yes                     25              265.1
# 1               yes                     26              161.6
# 2                no                      0              243.4
# 3                no                      0              299.4
# 4                no                      0              166.7
# ..              ...                    ...                ...
# 707             yes                     42              165.3
# 710              no                      0              195.3
# 760              no                      0              187.3
# 777             yes                     24              127.7
# 814             yes                     41              130.9
#
#      total day calls  total day charge  ...  total eve calls  \
# 0                110             45.07  ...               99
# 1                123             27.47  ...              103
# 2                114             41.38  ...              110
# 3                 71             50.90  ...               88
# 4                113             28.34  ...              122
# ..               ...               ...  ...              ...
# 707               97             28.10  ...              118
# 710               70             33.20  ...              108
# 760               84             31.84  ...               95
# 777               54             21.71  ...              105
# 814              115             22.25  ...              110
#
#      total eve charge  total night minutes  total night calls  \
# 0               16.78                244.7                 91
# 1               16.62                254.4                103
# 2               10.30                162.6                104
# 3                5.26                196.9                 89
# 4               12.61                186.9                121
# ..                ...                  ...                ...
# 707             19.00                260.8                 72
# 710             18.42                259.9                119
# 760             23.02                206.4                 68
# 777             18.28                234.3                 84
# 814             17.29                171.7                 68
#
#      total night charge  total intl minutes  total intl calls  \
# 0                 11.01                10.0                 3
# 1                 11.45                13.7                 3
# 2                  7.32                12.2                 5
# 3                  8.86                 6.6                 7
# 4                  8.41                10.1                 3
# ..                  ...                 ...               ...
# 707               11.74                 7.6                 7
# 710               11.70                12.5                 4
# 760                9.29                10.1                 5
# 777               10.54                 5.8                 4
# 814                7.73                12.4                 4
#
#      total intl charge  customer service calls  churn
# 0                 2.70                       1  False
# 1                 3.70                       1  False
# 2                 3.29                       0  False
# 3                 1.78                       2  False
# 4                 2.73                       3  False
# ..                 ...                     ...    ...
# 707               2.05                       3  False
# 710               3.38                       3  False
# 760               2.73                       1  False
# 777               1.57                       2  False
# 814               3.35                       1  False
#
# [153 rows x 21 columns]

# %% [markdown]
# Duplicates on the entire dataframe. If two rows are exactly alike, drop_duplicates() with no subset argument will remove the entire row.

# %% [markdown]
# <div class="alert alert-info" style="background-color:red; color:white; padding:0px 10px; border-radius:5px;"><h2 style='margin:10px 5px'>6. Sorting</h2>
# </div>

# %% [markdown]
# 1. Sorting by single column
# 2. Sorting by multiple columns
# 3. Mix ascending and descending sort

# %%
import pandas as pd
df = pd.read_csv(r"../Datasets/Churn.csv")
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# 0             45.07  ...               99             16.78
# 1             27.47  ...              103             16.62
# 2             41.38  ...              110             10.30
# 3             50.90  ...               88              5.26
# 4             28.34  ...              122             12.61
#
#    total night minutes  total night calls  total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
#
#    total intl minutes  total intl calls  total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    customer service calls  churn
# 0                       1  False
# 1                       1  False
# 2                       0  False
# 3                       2  False
# 4                       3  False
#
# [5 rows x 21 columns]

# %% [markdown]
# __Ascending sort__
#
# Ex: Get 5 customers who made the lowest number of total day calls.

# %%
df.sort_values(by='total day calls')
# Out:
#      state  account length  area code phone number international plan  \
# 1345    SD              98        415     392-2555                 no
# 1397    VT             101        510     413-7655                 no
# 1144    NH             155        408     353-6300                 no
# 1989    MT             124        415     420-5652                 no
# 692     NE              82        408     343-2741                 no
# ...    ...             ...        ...          ...                ...
# 2392    WY              90        510     400-8069                 no
# 1057    WV              86        415     332-2258                 no
# 1460    MT              80        415     361-8288                 no
# 468     AZ              86        415     392-2381                 no
# 1121    MI              91        415     390-7930                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# 1345              no                      0                0.0
# 1397              no                      0                0.0
# 1144              no                      0              216.7
# 1989             yes                     30              144.5
# 692               no                      0              185.8
# ...              ...                    ...                ...
# 2392              no                      0              125.4
# 1057             yes                     38              123.0
# 1460              no                      0              198.1
# 468              yes                     32               70.9
# 1121              no                      0              154.4
#
#       total day calls  total day charge  ...  total eve calls  \
# 1345                0              0.00  ...              130
# 1397                0              0.00  ...              119
# 1144               30             36.84  ...              125
# 1989               35             24.57  ...              101
# 692                36             31.59  ...              134
# ...               ...               ...  ...              ...
# 2392              158             21.32  ...               83
# 1057              158             20.91  ...              119
# 1460              160             33.68  ...               87
# 468               163             12.05  ...              121
# 1121              165             26.25  ...              121
#
#       total eve charge  total night minutes  total night calls  \
# 1345             13.57                167.1                 88
# 1397             16.33                168.8                 95
# 1144             12.27                135.3                106
# 1989             22.30                226.5                 82
# 692              23.50                192.1                104
# ...                ...                  ...                ...
# 2392             22.87                238.6                103
# 1057             11.38                138.2                103
# 1460             13.32                182.1                 76
# 468              14.17                244.9                105
# 1121             14.31                239.9                 81
#
#       total night charge  total intl minutes  total intl calls  \
# 1345                7.52                 6.8                 1
# 1397                7.60                 7.2                 4
# 1144                6.09                10.8                 1
# 1989               10.19                12.0                 7
# 692                 8.64                 5.7                 7
# ...                  ...                 ...               ...
# 2392               10.74                11.0                 7
# 1057                6.22                13.3                 4
# 1460                8.19                 9.3                 3
# 468                11.02                11.1                 5
# 1121               10.80                11.7                 4
#
#       total intl charge  customer service calls  churn
# 1345               1.84                       4   True
# 1397               1.94                       1  False
# 1144               2.92                       2  False
# 1989               3.24                       2  False
# 692                1.54                       4  False
# ...                 ...                     ...    ...
# 2392               2.97                       1  False
# 1057               3.59                       1  False
# 1460               2.51                       3  False
# 468                3.00                       3  False
# 1121               3.16                       5   True
#
# [3333 rows x 21 columns]

# %% [markdown]
# __Descending sort__
#
# Ex: Get 5 customers who made the highest number of day calls.

# %%
df.sort_values(by='total day calls', ascending=False)
# Out:
#      state  account length  area code phone number international plan  \
# 1121    MI              91        415     390-7930                 no
# 468     AZ              86        415     392-2381                 no
# 1460    MT              80        415     361-8288                 no
# 2392    WY              90        510     400-8069                 no
# 315     MA              39        408     332-2462                 no
# ...    ...             ...        ...          ...                ...
# 692     NE              82        408     343-2741                 no
# 1989    MT             124        415     420-5652                 no
# 1144    NH             155        408     353-6300                 no
# 1345    SD              98        415     392-2555                 no
# 1397    VT             101        510     413-7655                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# 1121              no                      0              154.4
# 468              yes                     32               70.9
# 1460              no                      0              198.1
# 2392              no                      0              125.4
# 315               no                      0               60.4
# ...              ...                    ...                ...
# 692               no                      0              185.8
# 1989             yes                     30              144.5
# 1144              no                      0              216.7
# 1345              no                      0                0.0
# 1397              no                      0                0.0
#
#       total day calls  total day charge  ...  total eve calls  \
# 1121              165             26.25  ...              121
# 468               163             12.05  ...              121
# 1460              160             33.68  ...               87
# 2392              158             21.32  ...               83
# 315               158             10.27  ...              120
# ...               ...               ...  ...              ...
# 692                36             31.59  ...              134
# 1989               35             24.57  ...              101
# 1144               30             36.84  ...              125
# 1345                0              0.00  ...              130
# 1397                0              0.00  ...              119
#
#       total eve charge  total night minutes  total night calls  \
# 1121             14.31                239.9                 81
# 468              14.17                244.9                105
# 1460             13.32                182.1                 76
# 2392             22.87                238.6                103
# 315              26.03                123.9                 46
# ...                ...                  ...                ...
# 692              23.50                192.1                104
# 1989             22.30                226.5                 82
# 1144             12.27                135.3                106
# 1345             13.57                167.1                 88
# 1397             16.33                168.8                 95
#
#       total night charge  total intl minutes  total intl calls  \
# 1121               10.80                11.7                 4
# 468                11.02                11.1                 5
# 1460                8.19                 9.3                 3
# 2392               10.74                11.0                 7
# 315                 5.58                12.4                 3
# ...                  ...                 ...               ...
# 692                 8.64                 5.7                 7
# 1989               10.19                12.0                 7
# 1144                6.09                10.8                 1
# 1345                7.52                 6.8                 1
# 1397                7.60                 7.2                 4
#
#       total intl charge  customer service calls  churn
# 1121               3.16                       5   True
# 468                3.00                       3  False
# 1460               2.51                       3  False
# 2392               2.97                       1  False
# 315                3.35                       1  False
# ...                 ...                     ...    ...
# 692                1.54                       4  False
# 1989               3.24                       2  False
# 1144               2.92                       2  False
# 1345               1.84                       4   True
# 1397               1.94                       1  False
#
# [3333 rows x 21 columns]

# %% [markdown]
# __Sort by multiple columns__

# %% [markdown]
# Ex: sort the customers who made the highest number of day calls by each state.

# %%
df.sort_values(by=['state', 'total day calls'], ascending=False).loc[:, ['state', 'total day calls']]
# Out:
#      state  total day calls
# 2392    WY              158
# 238     WY              148
# 1018    WY              148
# 1751    WY              142
# 49      WY              135
# ...    ...              ...
# 1024    AK               65
# 2571    AK               62
# 1884    AK               60
# 550     AK               58
# 1589    AK               55
#
# [3333 rows x 2 columns]

# %% [markdown]
# Sort one column by ascending and other by descending.
#
# Ex: Sort `state` in alphabetical order but `total day calls` in descending order.

# %%
df.sort_values(by=['state', 'total day calls'], ascending=[True, False]).loc[:, ['state', 'total day calls']]
# Out:
#      state  total day calls
# 950     AK              129
# 36      AK              128
# 3088    AK              127
# 718     AK              124
# 2071    AK              121
# ...    ...              ...
# 2819    WY               68
# 3172    WY               67
# 653     WY               65
# 609     WY               55
# 1422    WY               45
#
# [3333 rows x 2 columns]
