# %% [markdown]
# # __Membership Filtering__

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../Datasets/Churn.csv')
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %% [markdown]
# # isin() method

# %% [markdown]
# Syntax : DataFrame[column].isin(values)

# %% [markdown]
# .isin(values) checks if each element in the Series or DataFrame is present in the values.  <br />
# values can be a list, set, or any iterable. <br />
# It returns a boolean Series, which can be used for filtering. <br />

# %%
filter = df.state.isin(['NY', 'NJ'])
df[filter].head()
# Out:
#    state  account length  area code phone number international plan  \
# 2     NJ             137        415     358-1921                 no
# 15    NY             161        415     351-7269                 no
# 39    NJ             149        408     332-9891                 no
# 70    NJ             138        408     359-1231                 no
# 77    NY             144        408     360-1171                 no
#
#    voice mail plan  number vmail messages  total day minutes  total day calls  \
# 2               no                      0              243.4              114
# 15              no                      0              332.9               67
# 39              no                      0              140.4               94
# 70              no                      0              241.8               93
# 77              no                      0               61.6              117
#
#     total day charge  ...  total eve calls  total eve charge  \
# ...

# %% [markdown]
# ~ filter

# %% [markdown]
# only shows values except NY and NJ

# %%
filter = ~df.state.isin(['NY', 'NJ'])
df[filter].head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
# 5    AL             118        510     391-8027                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
# 5              no                      0              223.4               98
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %% [markdown]
# # between()

# %% [markdown]
# Checks if values fall between a range (inclusive by default).

# %% [markdown]
# Syntax : Series.between(left, right, inclusive="both")

# %%
filter = df['account length'].between(50,100)
df.loc[filter,:].head()
# Out:
#    state  account length  area code phone number international plan  \
# 3     OH              84        408     375-9999                yes
# 4     OK              75        415     330-6626                yes
# 10    IN              65        415     329-6603                 no
# 11    RI              74        415     344-9403                 no
# 13    MT              95        510     394-8006                 no
#
#    voice mail plan  number vmail messages  total day minutes  total day calls  \
# 3               no                      0              299.4               71
# 4               no                      0              166.7              113
# 10              no                      0              129.1              137
# 11              no                      0              187.7              127
# 13              no                      0              156.6               88
#
#     total day charge  ...  total eve calls  total eve charge  \
# ...

# %% [markdown]
# # any() and all()

# %% [markdown]
# any() : Checks if any value in a DataFrame or Series evaluates to True.

# %% [markdown]
# If any of one is True(1 or positive) returns True , else false

# %%
df = pd.DataFrame({'A': [0, 0, 1], 'B': [0, 1, 0]})
print(df['A'].any())  
print(df.any(axis=1))
# Out:
# True
# 0    False
# 1     True
# 2     True
# dtype: bool

# %% [markdown]
# all() : Checks if all values in a DataFrame or Series evaluate to True.

# %% [markdown]
# Series.all() <br/>
# DataFrame.all(axis=0)

# %%
print(df['A'].all())  
print(df.all(axis=1))
# Out:
# False
# 0    False
# 1    False
# 2    False
# dtype: bool

# %% [markdown]
# It Have default => axis = 'rows' ==>  returns result for every column <br />
# axis = 'column' ==> return results for every row

# %% [markdown]
# # __Query__

# %% [markdown]
# The .query() method in Pandas provides a concise way to filter rows based on logical conditions written as a string.

# %%
df = pd.read_csv('../Datasets/Churn.csv')
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
filter = df.query('state in ["NY", "NJ"]')
filter.head()
# Out:
#    state  account length  area code phone number international plan  \
# 2     NJ             137        415     358-1921                 no
# 15    NY             161        415     351-7269                 no
# 39    NJ             149        408     332-9891                 no
# 70    NJ             138        408     359-1231                 no
# 77    NY             144        408     360-1171                 no
#
#    voice mail plan  number vmail messages  total day minutes  total day calls  \
# 2               no                      0              243.4              114
# 15              no                      0              332.9               67
# 39              no                      0              140.4               94
# 70              no                      0              241.8               93
# 77              no                      0               61.6              117
#
#     total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
df.query('`account length` >= 50 and `account length` <= 100').head()
# Out:
#    state  account length  area code phone number international plan  \
# 3     OH              84        408     375-9999                yes
# 4     OK              75        415     330-6626                yes
# 10    IN              65        415     329-6603                 no
# 11    RI              74        415     344-9403                 no
# 13    MT              95        510     394-8006                 no
#
#    voice mail plan  number vmail messages  total day minutes  total day calls  \
# 3               no                      0              299.4               71
# 4               no                      0              166.7              113
# 10              no                      0              129.1              137
# 11              no                      0              187.7              127
# 13              no                      0              156.6               88
#
#     total day charge  ...  total eve calls  total eve charge  \
# ...

# %% [markdown]
# We can use python variable also in query

# %%
min_day_calls = 100
set = ('KS', 'OH', 'NV')
filter = df.query('`total day calls` > @min_day_calls and state in @set')
filter.head()
# Out:
#     state  account length  area code phone number international plan  \
# 0      KS             128        415     382-4657                 no
# 1      OH             107        415     371-7191                 no
# 73     NV              90        415     399-4246                 no
# 117    NV              74        415     355-6837                 no
# 124    NV             130        510     408-4195                 no
#
#     voice mail plan  number vmail messages  total day minutes  \
# 0               yes                     25              265.1
# 1               yes                     26              161.6
# 73               no                      0              203.4
# 117              no                      0              282.5
# 124              no                      0              154.2
#
#      total day calls  total day charge  ...  total eve calls  \
# 0                110             45.07  ...               99
# ...

# %% [markdown]
# # Query is faster than .loc

# %% [markdown]
# # __Eval__

# %% [markdown]
# The .eval() method is used for evaluating mathematical expressions or logical operations on columns in a DataFrame. It provides a faster alternative to direct computations using Python syntax.

# %% [markdown]
# DataFrame.eval(expr, inplace=False, engine='numexpr')

# %%
df.eval('minutes_per_call = `total day minutes` / `total day calls`', inplace=True)
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve charge  total night minutes  \
# ...
