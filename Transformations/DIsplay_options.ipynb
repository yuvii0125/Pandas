# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'../Datasets/Student_Depression_Data.csv')
df.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#       Sleep Duration Dietary Habits   Degree  \
# 0          5-6 hours        Healthy  B.Pharm
# 1          5-6 hours       Moderate      BSc
# 2  Less than 5 hours        Healthy       BA
# ...

# %% [markdown]
# # Rows to Display

# %%
# pd.options.display.max_rows = None

# %%
pd.set_option('display.max_rows',5)
df
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# ...       ...     ...   ...            ...        ...                ...
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0                0.0  8.97                 2.0               0.0
# 1                0.0  5.90                 5.0               0.0
# ...              ...   ...                 ...               ...
# 27899            0.0  6.88                 2.0               0.0
# 27900            0.0  9.24                 1.0               0.0
#
#           Sleep Duration Dietary Habits    Degree  \
# 0              5-6 hours        Healthy   B.Pharm
# ...

# %% [markdown]
# # Columns to Display

# %%
pd.set_option('display.max_columns',10)
df
# Out:
#            id  Gender   Age           City Profession  ...  \
# 0           2    Male  33.0  Visakhapatnam    Student  ...
# 1           8  Female  24.0      Bangalore    Student  ...
# ...       ...     ...   ...            ...        ...  ...
# 27899  140690  Female  18.0       Ludhiana    Student  ...
# 27900  140699    Male  27.0          Patna    Student  ...
#
#        Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 0                                        Yes               3.0
# 1                                         No               3.0
# ...                                      ...               ...
# 27899                                    Yes              10.0
# 27900                                    Yes               2.0
#
#        Financial Stress  Family History of Mental Illness  Depression
# 0                   1.0                                No           1
# 1                   2.0                               Yes           0
# ...

# %% [markdown]
# pd.set_option('display.max_colwidth',) #Col width

# %% [markdown]
# # __Precison and float format__

# %% [markdown]
# pd.options.display.float_format = '{:,2f}%'.format

# %% [markdown]
# pd.options.display.precision = 4 (Preciosn in floating number)

# %%
pd.set_option('display.precision', 4)
df
# Out:
#            id  Gender   Age           City Profession  ...  \
# 0           2    Male  33.0  Visakhapatnam    Student  ...
# 1           8  Female  24.0      Bangalore    Student  ...
# ...       ...     ...   ...            ...        ...  ...
# 27899  140690  Female  18.0       Ludhiana    Student  ...
# 27900  140699    Male  27.0          Patna    Student  ...
#
#        Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 0                                        Yes               3.0
# 1                                         No               3.0
# ...                                      ...               ...
# 27899                                    Yes              10.0
# 27900                                    Yes               2.0
#
#        Financial Stress  Family History of Mental Illness  Depression
# 0                   1.0                                No           1
# 1                   2.0                               Yes           0
# ...

# %%
pd.set_option('display.float_format', '{:.2f}%'.format)

# %%
pd.set_option('display.float_format', lambda x: f'{x:.3f}')

# %%
pd.set_option('display.precision', 3)
pd.set_option('display.float_format', lambda x: f'{x:.3f}')

# Example DataFrame
df = pd.DataFrame({'A': [1.123456, 2.987654], 'B': [0.12345, 1.98765]})
print(df)
# Out:
#       A     B
# 0 1.123 0.123
# 1 2.988 1.988

# %% [markdown]
# # __Resetting Options__

# %%
pd.reset_option('display.precision') 
pd.reset_option('display.max_rows') 
pd.reset_option('display.max_columns') 
pd.reset_option('display.max_colwidth') 
pd.reset_option('display.float_format')

# %% [markdown]
# __For getting Current Value of options__

# %%
pd.get_option('display.precision')
# Out:
# 6
