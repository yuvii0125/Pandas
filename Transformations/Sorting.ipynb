# %% [markdown]
# # __Sorting__

# %% [markdown]
# 1. Sorting by column <br />
# 2. Sorting by Multiple columns <br />
# 3. Mix ascending and descending sorts

# %%
import pandas as pd

# %%
df = pd.read_csv('../Datasets/Churn.csv')
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %% [markdown]
# we can sort using the .sort method

# %%
df.sort_values(by='account length').head()
# Out:
#      state  account length  area code phone number international plan  \
# 1409    NJ               1        415     420-6780                 no
# 923     MS               1        415     408-3977                 no
# 2879    SC               1        415     356-8621                 no
# 2960    TX               1        415     396-4254                 no
# 1490    TN               1        415     335-5591                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# 1409             yes                     30              183.1
# 923               no                      0              144.8
# 2879             yes                     26              146.6
# 2960              no                      0              182.1
# 1490              no                      0              196.1
#
#       total day calls  total day charge  ...  total eve calls  \
# 1409               95             31.13  ...              110
# ...

# %% [markdown]
# By default, the sort_values() method sorts the data in ascending order.

# %% [markdown]
# ## Sort by multiple columns

# %%
df.sort_values(by=['account length', 'total day charge']).head()
# Out:
#      state  account length  area code phone number international plan  \
# 2423    SC               1        408     336-1043                 no
# 923     MS               1        415     408-3977                 no
# 2879    SC               1        415     356-8621                 no
# 2475    AK               1        408     373-1028                 no
# 2960    TX               1        415     396-4254                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# 2423              no                      0              123.8
# 923               no                      0              144.8
# 2879             yes                     26              146.6
# 2475              no                      0              175.2
# 2960              no                      0              182.1
#
#       total day calls  total day charge  ...  total eve calls  \
# 2423              113             21.05  ...               77
# ...

# %% [markdown]
# We can change order of sorting Ascending / Descending

# %%
df.sort_values(by=['account length', 'total day charge'], ascending=[True, False]).head()
# Out:
#      state  account length  area code phone number international plan  \
# 1838    IA               1        408     331-2144                 no
# 1490    TN               1        415     335-5591                 no
# 1409    NJ               1        415     420-6780                 no
# 2960    TX               1        415     396-4254                 no
# 2475    AK               1        408     373-1028                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# 1838             yes                     26              208.0
# 1490              no                      0              196.1
# 1409             yes                     30              183.1
# 2960              no                      0              182.1
# 2475              no                      0              175.2
#
#       total day calls  total day charge  ...  total eve calls  \
# 1838              115             35.36  ...              113
# ...
