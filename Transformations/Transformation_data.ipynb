# %% [markdown]
# ## Assign , apply and map functions

# %% [markdown]
# ## 1.assign  <br />
# Used to add or modify columns in a DataFrame.  <br />
# Creates a new DataFrame without modifying the original one. <br />
# You can pass a function or a value to create new columns.

# %% [markdown]
# ### Syntax : DataFrame.assign(new_col_name=function_or_value)

# %%
import pandas as pd

df = pd.DataFrame({
    'A': [1, 2, 3],
    'B': [4, 5, 6]
})

# Add a new column 'C' as the sum of 'A' and 'B'
new_df = df.assign(C=df['A'] + df['B'])

print(new_df)
# Out:
#    A  B  C
# 0  1  4  5
# 1  2  5  7
# 2  3  6  9

# %%
print(df)
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %% [markdown]
# ### assign creates new DataFrame

# %%
df = pd.read_csv(r"../Datasets/Churn.csv")
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
new_df = df.assign(Churn = df['churn'].astype(int))
new_df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve charge  total night minutes  \
# ...

# %%
new = df.assign(small_state=df['state'].str.lower())
new.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve charge  total night minutes  \
# ...

# %% [markdown]
# ## 2.map  <br />
# Used for element-wise transformations on an entire DataFrame. <br />
# Applies a function to each individual element of the DataFrame.  <br />

# %%
import pandas as pd

df = pd.DataFrame({
    'A': [1, 2, 3],
    'B': [4, 5, 6]
})

# Apply a function to each element in the DataFrame
result = df.map(lambda x: x ** 2)

print(result)
# Out:
#    A   B
# 0  1  16
# 1  4  25
# 2  9  36

# %% [markdown]
# ## 3. apply  <br />
# Used to apply a function along a specific axis of a DataFrame (row-wise or column-wise).<br />
# Can be used for row-level, column-level, or element-wise transformations, depending on the axis specified.<br />

# %% [markdown]
# Syntax : DataFrame.apply(function, axis=0)  # Default: Column-wise (axis=0)   <br />
# DataFrame.apply(function, axis=1)  # Row-wise (axis=1)  <br />
# Series.apply(function)             # For Series  <br />

# %%
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
# Apply a function to specific columns
df['Column1'] = df['account length'].apply(lambda x: x * 2)
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve charge  total night minutes  \
# ...

# %%
df = df[['state', 'account length', 'Column1', 'phone number', 'international plan', 'voice mail plan', 'number vmail messages', 'total day minutes', 'total day calls', 'total day charge', 'total eve minutes', 'total eve calls', 'total eve charge', 'total night minutes', 'total night calls', 'total night charge', 'total intl minutes', 'total intl calls', 'total intl charge', 'customer service calls', 'churn', 'area code']]

# %%
df.head()
# Out:
#   state  account length  Column1 phone number international plan  \
# 0    KS             128      256     382-4657                 no
# 1    OH             107      214     371-7191                 no
# 2    NJ             137      274     358-1921                 no
# 3    OH              84      168     375-9999                yes
# 4    OK              75      150     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve charge  total night minutes  \
# ...
